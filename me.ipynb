# %%
from tensorflow import keras
import tensorflow as tf
import numpy as np
import pandas as pd
df=pd.read_csv('c.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ReferenceAllele       25000 non-null  object
#  1   AlternateAllele       25000 non-null  object
#  2   Chromosome            25000 non-null  object
#  3   Start                 25000 non-null  int64
#  4   Stop                  25000 non-null  int64
#  5   GeneSymbol            25000 non-null  object
#  6   ClinicalSignificance  25000 non-null  object
#  7   PhenotypeList         25000 non-null  object
#  8   Type                  25000 non-null  object
#  9   Assembly              25000 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 1.9+ MB

# %%
df.isnull().sum()
# Out:
# ReferenceAllele         0
# AlternateAllele         0
# Chromosome              0
# Start                   0
# Stop                    0
# GeneSymbol              0
# ClinicalSignificance    0
# PhenotypeList           0
# Type                    0
# Assembly                0
# dtype: int64

# %%
df['AlternateAllele'].value_counts()
# Out:
# AlternateAllele
# na                     24992
# GG                         2
# ATAAATCACTTAGAGATGT        2
# CTA                        2
# C(2_7)                     2
# Name: count, dtype: int64

# %%
df['Assembly'].value_counts()
# Out:
# Assembly
# GRCh38    12354
# GRCh37    12276
# na          369
# NCBI36        1
# Name: count, dtype: int64

# %%
df['ClinicalSignificance'].value_counts()
# Out:
# ClinicalSignificance
# Pathogenic                                                                15830
# Pathogenic/Likely pathogenic                                               3210
# Conflicting classifications of pathogenicity                               1568
# Likely pathogenic                                                          1420
# Uncertain significance                                                     1331
#                                                                           ...
# association; drug response; risk factor                                       2
# Benign/Likely benign; association                                             2
# Conflicting classifications of pathogenicity; association; risk factor        2
# Uncertain significance; Affects                                               2
# Pathogenic; protective                                                        2
# Name: count, Length: 61, dtype: int64

# %%
import pandas as pd

df = pd.read_csv("variant_summary.txt", sep="\t", low_memory=False)

# %%
df.shape
# Out:
# (7449992, 43)

# %%
df.head()
# Out:
#    #AlleleID                       Type  \
# 0      15041                      Indel
# 1      15041                      Indel
# 2      15042                   Deletion
# 3      15042                   Deletion
# 4      15043  single nucleotide variant
#
#                                                 Name  GeneID GeneSymbol  \
# 0  NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...    9907      AP5Z1
# 1  NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...    9907      AP5Z1
# 2     NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)    9907      AP5Z1
# 3     NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)    9907      AP5Z1
# 4       NM_014630.3(ZNF592):c.3136G>A (p.Gly1046Arg)    9640     ZNF592
#
#       HGNC_ID          ClinicalSignificance  ClinSigSimple LastEvaluated  \
# 0  HGNC:22197  Pathogenic/Likely pathogenic              1  Dec 17, 2024
# 1  HGNC:22197  Pathogenic/Likely pathogenic              1  Dec 17, 2024
# 2  HGNC:22197                    Pathogenic              1  Jun 29, 2010
# 3  HGNC:22197                    Pathogenic              1  Jun 29, 2010
# 4  HGNC:28986        Uncertain significance              0  Jun 29, 2015
#
#    RS# (dbSNP)  ...      AlternateAlleleVCF SomaticClinicalImpact  \
# 0    397704705  ...  TGCTGTAAACTGTAACTGTAAA                     -
# 1    397704705  ...  TGCTGTAAACTGTAACTGTAAA                     -
# 2    397704709  ...                       G                     -
# 3    397704709  ...                       G                     -
# 4    150829393  ...                       A                     -
#
#   SomaticClinicalImpactLastEvaluated ReviewStatusClinicalImpact Oncogenicity  \
# 0                                  -                          -            -
# 1                                  -                          -            -
# 2                                  -                          -            -
# 3                                  -                          -            -
# 4                                  -                          -            -
#
#   OncogenicityLastEvaluated ReviewStatusOncogenicity  \
# 0                         -                        -
# 1                         -                        -
# 2                         -                        -
# 3                         -                        -
# 4                         -                        -
#
#    SCVsForAggregateGermlineClassification  \
# 0  SCV001451119|SCV005622007|SCV005909190
# 1  SCV001451119|SCV005622007|SCV005909190
# 2                            SCV000020156
# 3                            SCV000020156
# 4                            SCV000020157
#
#   SCVsForAggregateSomaticClinicalImpact  \
# 0                                     -
# 1                                     -
# 2                                     -
# 3                                     -
# 4                                     -
#
#    SCVsForAggregateOncogenicityClassification
# 0                                           -
# 1                                           -
# 2                                           -
# 3                                           -
# 4                                           -
#
# [5 rows x 43 columns]

# %%
df.isnull().sum()
# Out:
# #AlleleID                                     0
# Type                                          0
# Name                                          0
# GeneID                                        0
# GeneSymbol                                    0
# HGNC_ID                                       0
# ClinicalSignificance                          0
# ClinSigSimple                                 0
# LastEvaluated                                 0
# RS# (dbSNP)                                   0
# nsv/esv (dbVar)                               0
# RCVaccession                                  0
# PhenotypeIDS                                  0
# PhenotypeList                                 0
# Origin                                        0
# OriginSimple                                  0
# Assembly                                      0
# ChromosomeAccession                           0
# Chromosome                                    0
# Start                                         0
# Stop                                          0
# ReferenceAllele                               0
# AlternateAllele                               0
# Cytogenetic                                   0
# ReviewStatus                                  0
# NumberSubmitters                              0
# Guidelines                                    0
# TestedInGTR                                   0
# OtherIDs                                      0
# SubmitterCategories                           0
# VariationID                                   0
# PositionVCF                                   0
# ReferenceAlleleVCF                            0
# AlternateAlleleVCF                            0
# SomaticClinicalImpact                         0
# SomaticClinicalImpactLastEvaluated            0
# ReviewStatusClinicalImpact                    0
# Oncogenicity                                  0
# OncogenicityLastEvaluated                     0
# ReviewStatusOncogenicity                      0
# SCVsForAggregateGermlineClassification        0
# SCVsForAggregateSomaticClinicalImpact         0
# SCVsForAggregateOncogenicityClassification    0
# dtype: int64

# %%
df.duplicated().sum()

# %%
df.drop_duplicates()
# Out:
#          #AlleleID                       Type  \
# 0            15041                      Indel
# 1            15041                      Indel
# 2            15042                   Deletion
# 3            15042                   Deletion
# 4            15043  single nucleotide variant
# ...            ...                        ...
# 7449987    4185313  single nucleotide variant
# 7449988    4185325  single nucleotide variant
# 7449989    4185325  single nucleotide variant
# 7449990    4185326  single nucleotide variant
# 7449991    4185326  single nucleotide variant
#
#                                                       Name  GeneID GeneSymbol  \
# 0        NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...    9907      AP5Z1
# 1        NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...    9907      AP5Z1
# 2           NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)    9907      AP5Z1
# 3           NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)    9907      AP5Z1
# 4             NM_014630.3(ZNF592):c.3136G>A (p.Gly1046Arg)    9640     ZNF592
# ...                                                    ...     ...        ...
# 7449987              NM_000518.5(HBB):c.82G>A (p.Ala28Thr)    3043        HBB
# 7449988        NM_000059.4(BRCA2):c.8020A>T (p.Lys2674Ter)     675      BRCA2
# 7449989        NM_000059.4(BRCA2):c.8020A>T (p.Lys2674Ter)     675      BRCA2
# 7449990          NM_000252.3(MTM1):c.1248T>G (p.His416Gln)    4534       MTM1
# 7449991          NM_000252.3(MTM1):c.1248T>G (p.His416Gln)    4534       MTM1
#
#             HGNC_ID          ClinicalSignificance  ClinSigSimple  \
# 0        HGNC:22197  Pathogenic/Likely pathogenic              1
# 1        HGNC:22197  Pathogenic/Likely pathogenic              1
# 2        HGNC:22197                    Pathogenic              1
# 3        HGNC:22197                    Pathogenic              1
# 4        HGNC:28986        Uncertain significance              0
# ...             ...                           ...            ...
# 7449987   HGNC:4827             Likely pathogenic              1
# 7449988   HGNC:1101             Likely pathogenic              1
# 7449989   HGNC:1101             Likely pathogenic              1
# 7449990   HGNC:7448        Uncertain significance              0
# 7449991   HGNC:7448        Uncertain significance              0
#
#         LastEvaluated  RS# (dbSNP)  ...      AlternateAlleleVCF  \
# 0        Dec 17, 2024    397704705  ...  TGCTGTAAACTGTAACTGTAAA
# 1        Dec 17, 2024    397704705  ...  TGCTGTAAACTGTAACTGTAAA
# 2        Jun 29, 2010    397704709  ...                       G
# 3        Jun 29, 2010    397704709  ...                       G
# 4        Jun 29, 2015    150829393  ...                       A
# ...               ...          ...  ...                     ...
# 7449987  Jan 02, 2024           -1  ...                       T
# 7449988  Jul 25, 2025           -1  ...                       T
# 7449989  Jul 25, 2025           -1  ...                       T
# 7449990  Dec 19, 2024           -1  ...                       G
# 7449991  Dec 19, 2024           -1  ...                       G
#
#         SomaticClinicalImpact SomaticClinicalImpactLastEvaluated  \
# 0                           -                                  -
# 1                           -                                  -
# 2                           -                                  -
# 3                           -                                  -
# 4                           -                                  -
# ...                       ...                                ...
# 7449987                     -                                  -
# 7449988                     -                                  -
# 7449989                     -                                  -
# 7449990                     -                                  -
# 7449991                     -                                  -
#
#         ReviewStatusClinicalImpact Oncogenicity OncogenicityLastEvaluated  \
# 0                                -            -                         -
# 1                                -            -                         -
# 2                                -            -                         -
# 3                                -            -                         -
# 4                                -            -                         -
# ...                            ...          ...                       ...
# 7449987                          -            -                         -
# 7449988                          -            -                         -
# 7449989                          -            -                         -
# 7449990                          -            -                         -
# 7449991                          -            -                         -
#
#         ReviewStatusOncogenicity  SCVsForAggregateGermlineClassification  \
# 0                              -  SCV001451119|SCV005622007|SCV005909190
# 1                              -  SCV001451119|SCV005622007|SCV005909190
# 2                              -                            SCV000020156
# 3                              -                            SCV000020156
# 4                              -                            SCV000020157
# ...                          ...                                     ...
# 7449987                        -                            SCV006301624
# 7449988                        -                            SCV006301634
# 7449989                        -                            SCV006301634
# 7449990                        -                            SCV006301671
# 7449991                        -                            SCV006301671
#
#         SCVsForAggregateSomaticClinicalImpact  \
# 0                                           -
# 1                                           -
# 2                                           -
# 3                                           -
# 4                                           -
# ...                                       ...
# 7449987                                     -
# 7449988                                     -
# 7449989                                     -
# 7449990                                     -
# 7449991                                     -
#
#          SCVsForAggregateOncogenicityClassification
# 0                                                 -
# 1                                                 -
# 2                                                 -
# 3                                                 -
# 4                                                 -
# ...                                             ...
# 7449987                                           -
# 7449988                                           -
# 7449989                                           -
# 7449990                                           -
# 7449991                                           -
#
# [7449992 rows x 43 columns]
